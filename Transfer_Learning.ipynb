# %% [markdown]
# DHIA SALSABILA AZHAR
#
# 18/430187/PA/18700

# %% [markdown]
# ### Pendahuluan
#
# [Keras](https://github.com/keras-team/keras/blob/master/README.md) memiliki banyak model *deep learning* untuk klasifikasi gambar yang siap pakai. Dengan mengatur parameter ``weights='imagenet'``, *weight* hasil *training* berhari-hari pada jutaan gambar dari dataset ImageNet otomatis di*download*. Tanpa kita *training* di PC sendiri, model dapat kita masukkan gambar sembarang untuk diklasifikasi.
#
# Jumlah kelas dataset ImageNet sangat banyak, ada 1000. Perhatikan sampel berikut.
#
# >#### ImageNet [classes.txt](https://github.com/xmartlabs/caffeflow/blob/master/examples/imagenet/imagenet-classes.txt)
# >... head cabbage broccoli cauliflower zucchini, courgette spaghetti squash acorn squash butternut squash cucumber, cuke artichoke, globe artichoke bell pepper cardoon mushroom Granny Smith strawberry orange lemon fig pineapple, ananas **banana** jackfruit, jak, jack custard apple pomegranate ...
#
# Model mampu membedakan berbagai sayur dan buah. Akan tetapi, model tidak cukup spesifik untuk membedakan varian dari setiap sayur atau buah dalam perbendaharaannya. Model akan memprediksi, misalnya, 'orange' ketika dimasukkan gambar jeruk mandarin maupun jeruk sunkist. Pada artikel ini kita akan membuat model yang khusus membedakan antara **pisang tanduk** dan **pisang kepok**. Kita akan menggunakan salah satu model yang disediakan Keras, DenseNet121.

# %% [markdown]
# ### DenseNet
#
# DenseNet models {121, 169, 201}, with weights pre-trained on ImageNet.
#
# This model and can be built both with 'channels_first' data format (channels, height, width) or 'channels_last' data format (height, width, channels).
#
# The default input size for this model is 224x224.
#
# ```
# keras.applications.densenet.DenseNet121(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000)
#
# ```
#
# #### Arguments
# + blocks: numbers of building blocks for the four dense layers.
# + include_top: whether to include the fully-connected layer at the top of the network.
# + weights: one of None (random initialization), 'imagenet' (pre-training on ImageNet), or the path to the weights file to be loaded.
# + input_tensor: optional Keras tensor (i.e. output of layers.Input()) to use as image input for the model.
# + input_shape: optional shape tuple, only to be specified if include_top is False (otherwise the input shape has to be (224, 224, 3) (with 'channels_last' data format) or (3, 224, 224) (with 'channels_first' data format). It should have exactly 3 inputs channels, and width and height should be no smaller than 32. E.g. (200, 200, 3) would be one valid value.
# + pooling: optional pooling mode for feature extraction when include_top is False. None means that the output of the model will be the 4D tensor output of the last convolutional layer. avg means that global average pooling will be applied to the output of the last convolutional layer, and thus the output of the model will be a 2D tensor. max means that global max pooling will be applied.
# + classes: optional number of classes to classify images into, only to be specified if include_top is True, and if no weights argument is specified.

# %% [markdown]
# ### Imports
#
# Import secukupnya :)

# %%
from keras.applications import densenet
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.densenet import preprocess_input, decode_predictions
import numpy as np
from keras.layers import Dense, GlobalAveragePooling2D
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import os
import matplotlib.pyplot as plt

# %% [markdown]
# ### DataSet
#
# Gunakan dataset Magnetic Tiles dataset pada Praktikum 4 : Inspeksi Cacat Bahan (Magnetic Tiles Defect).
#
# Simpan gambar-gambar pisang sehingga struktur folder kita menjadi seperti berikut.
#
#     image_train/
#         MT_Blowhole/
#             ...
#         MT_Break/
#             ...
#         MT_Crack/
#             ...
#         MT_Fray/
#             ...
#         MT_Free/
#             ...
#     image_test/
#         MTBLW001.jpg
#         MTBLW002.jpg
#         ...
#         MTCRK018.jpg
#         MTFREE001.jpg
#         MTFREE002.jpg
#         ...
#         MTUNEVEN018.jpg
#
# Catatan: penamaan data *train* bebas, sedangkan nama file data *test* sebaiknya mengandung kelasnya untuk mempermudah membaca hasil prediksi nanti.
#
# Tempatkan dataset pada Google Colabs kalian sebagai contoh di dalam folder : Colab Notebooks/dataset tiles defect

# %%
from google.colab import drive

# mounting dataset from gdrive
drive.mount('/content/gdrive', force_remount=True)

# dataset path
root_path = '/content/gdrive/My Drive/dataset tiles defect/dataset tiles defect'

print("Path root:", root_path)
# Out:
# Mounted at /content/gdrive
# Path root: /content/gdrive/My Drive/dataset tiles defect/dataset tiles defect

# %% [markdown]
# ### READ DATASET

# %%
train_datagen = ImageDataGenerator(rescale=1./255,horizontal_flip = True)

train_generator = train_datagen.flow_from_directory(root_path + '/image_train', 
                                                    target_size=(224,224), 
                                                    color_mode='rgb', 
                                                    batch_size=32, 
                                                    class_mode='categorical', 
                                                    shuffle=True)
category_dict = train_generator.class_indices
print(category_dict)
# Out:
# Found 1254 images belonging to 6 classes.
# {'MT_Blowhole': 0, 'MT_Break': 1, 'MT_Crack': 2, 'MT_Fray': 3, 'MT_Free': 4, 'MT_Uneven': 5}

# %%
number_of_classes = len(category_dict)

default_model = VGG16(weights='imagenet', include_top=False, input_shape=(150,150,3))

x = default_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(512, activation='relu')(x)
x = Dense(512, activation='relu')(x)
x = Dense(256, activation='relu')(x)
preds_ = Dense(number_of_classes, activation='softmax')(x)

def_model = Model(inputs=default_model.input, outputs=preds_)

n_freeze = 300
for layer in model.layers[:n_freeze]:
    layer.trainable=False
for layer in model.layers[n_freeze:]:
    layer.trainable=True

print(len(model.layers))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step

# %% [markdown]
# Catatan: Jumlah layer dapat diketahui dengan ```print(len(model.layers))```.
#
# Perintah terakhir mengatur supaya 300 layer pertama di*freeze*, yakni hanya layer ke 301 sampai layer sebelum *output* saja yang di*train* parameternya. Jika mau, kita juga dapat mengatur supaya hanya layer *output* saja yang di*train* (murni *transfer learning*) seperti berikut.
#
#     for layer in model.layers:
#         layer.trainable=False

# %% [markdown]
# ```decode_predictions``` dapat digunakan untuk membuat keluaran model (*array* 1000 kelas) menjadi *human-readable*.
# ```
# prediction = model.predict(x)
# keras.applications.densenet.decode_predictions(prediction, top=2)
# ```
# Kebutuhan pengujian model kita dapat diimplementasi dengan *get key by value in dictionary*. (Saya kesulitan mencari *method* serupa yang lebih generik, yakni dapat digunakan untuk *transfer learning* dengan jumlah kelas ≠ 1000.)

# %%
test_path = root_path+'/image_test/'

for directory in os.listdir(test_path):
    
    # Load image.
    img_path = test_path+directory
    img = image.load_img(img_path, target_size=(224, 224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)

    preds = def_model.predict(x)
    default_preds = def_model.predict(x)

    # Printing results.

    # Default 1000 classes (without transfer learning).

    # Print transfer learning model top-1
    confidence_array = preds[0]
    index_max = np.argmax(confidence_array)

    confidence_array_notrf = default_preds[0]
    index_max_notrf = np.argmax(confidence_array_notrf)

    # Get KEY (category) by VALUE (index_max) in dictionary
    # mydict = {'george':16,'amber':19}
    # print(list(mydict.keys())[list(mydict.values()).index(16)]) # Example in one line.

    category_names = category_dict.keys()
    category_values = category_dict.values()
    category_at_index = list(category_values).index(index_max_notrf)
    category_max = list(category_names)[category_at_index]
    
    print(f"Without Transfer Learning Top-2 [{directory}]: \nTop-1 (confidence)\n{category_max} ({max(confidence_array)*100}%)")

    category_at_index = list(category_values).index(index_max)
    category_max = list(category_names)[category_at_index]

    print(f"\nWith Transfer Learning [{directory}]: \nTop-1 (confidence)\n{category_max} ({max(confidence_array)*100}%)")

    # Print transfer learning model all classes
    print("\nClass (confidence)")

    for category in category_dict:
        category_index = category_dict[category]
        value = confidence_array[category_index] * 100
        print(f"{category} ({value}%)")

    print("\n============================\n")
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 150, 150, 3) for input Tensor("input_1:0", shape=(None, 150, 150, 3), dtype=float32), but it was called on an input with incompatible shape (None, 224, 224, 3).
# Without Transfer Learning Top-2 [MTFRY002.jpg]:
# Top-1 (confidence)
# MT_Uneven (18.681561946868896%)
#
# With Transfer Learning [MTFRY002.jpg]:
# Top-1 (confidence)
# MT_Uneven (18.681561946868896%)
#
# Class (confidence)
# MT_Blowhole (17.698021233081818%)
# MT_Break (14.204610884189606%)
# MT_Crack (13.368022441864014%)
# MT_Fray (17.8570494055748%)
# MT_Free (18.190734088420868%)
# MT_Uneven (18.681561946868896%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTUNEVEN002.jpg]:
# Top-1 (confidence)
# MT_Uneven (18.85906010866165%)
#
# With Transfer Learning [MTUNEVEN002.jpg]:
# Top-1 (confidence)
# MT_Uneven (18.85906010866165%)
#
# Class (confidence)
# MT_Blowhole (16.35918766260147%)
# MT_Break (14.300143718719482%)
# MT_Crack (13.796254992485046%)
# MT_Fray (17.972087860107422%)
# MT_Free (18.71325969696045%)
# MT_Uneven (18.85906010866165%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBLW007.jpg]:
# Top-1 (confidence)
# MT_Fray (20.334358513355255%)
#
# With Transfer Learning [MTBLW007.jpg]:
# Top-1 (confidence)
# MT_Fray (20.334358513355255%)
#
# Class (confidence)
# MT_Blowhole (16.22583568096161%)
# MT_Break (14.300373196601868%)
# MT_Crack (14.862826466560364%)
# MT_Fray (20.334358513355255%)
# MT_Free (17.751798033714294%)
# MT_Uneven (16.52481257915497%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTUNEVEN001.jpg]:
# Top-1 (confidence)
# MT_Free (18.804097175598145%)
#
# With Transfer Learning [MTUNEVEN001.jpg]:
# Top-1 (confidence)
# MT_Free (18.804097175598145%)
#
# Class (confidence)
# MT_Blowhole (16.77713841199875%)
# MT_Break (14.906488358974457%)
# MT_Crack (13.670504093170166%)
# MT_Fray (18.09163987636566%)
# MT_Free (18.804097175598145%)
# MT_Uneven (17.75013357400894%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTUNEVEN016.jpg]:
# Top-1 (confidence)
# MT_Free (18.6765655875206%)
#
# With Transfer Learning [MTUNEVEN016.jpg]:
# Top-1 (confidence)
# MT_Free (18.6765655875206%)
#
# Class (confidence)
# MT_Blowhole (16.98506325483322%)
# MT_Break (14.836226403713226%)
# MT_Crack (13.605009019374847%)
# MT_Fray (17.32047200202942%)
# MT_Free (18.6765655875206%)
# MT_Uneven (18.576663732528687%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTUNEVEN022.jpg]:
# Top-1 (confidence)
# MT_Free (18.805119395256042%)
#
# With Transfer Learning [MTUNEVEN022.jpg]:
# Top-1 (confidence)
# MT_Free (18.805119395256042%)
#
# Class (confidence)
# MT_Blowhole (16.88670516014099%)
# MT_Break (14.07884657382965%)
# MT_Crack (13.959529995918274%)
# MT_Fray (17.9532527923584%)
# MT_Free (18.805119395256042%)
# MT_Uneven (18.316547572612762%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBRK013.jpg]:
# Top-1 (confidence)
# MT_Free (18.320339918136597%)
#
# With Transfer Learning [MTBRK013.jpg]:
# Top-1 (confidence)
# MT_Free (18.320339918136597%)
#
# Class (confidence)
# MT_Blowhole (17.266470193862915%)
# MT_Break (14.690864086151123%)
# MT_Crack (14.103923738002777%)
# MT_Fray (17.659305036067963%)
# MT_Free (18.320339918136597%)
# MT_Uneven (17.959095537662506%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFREE019.jpg]:
# Top-1 (confidence)
# MT_Free (18.724463880062103%)
#
# With Transfer Learning [MTFREE019.jpg]:
# Top-1 (confidence)
# MT_Free (18.724463880062103%)
#
# Class (confidence)
# MT_Blowhole (16.81313067674637%)
# MT_Break (14.429603517055511%)
# MT_Crack (13.848111033439636%)
# MT_Fray (17.766734957695007%)
# MT_Free (18.724463880062103%)
# MT_Uneven (18.417955935001373%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTCRK001.jpg]:
# Top-1 (confidence)
# MT_Fray (19.137011468410492%)
#
# With Transfer Learning [MTCRK001.jpg]:
# Top-1 (confidence)
# MT_Fray (19.137011468410492%)
#
# Class (confidence)
# MT_Blowhole (16.869907081127167%)
# MT_Break (14.716236293315887%)
# MT_Crack (13.431468605995178%)
# MT_Fray (19.137011468410492%)
# MT_Free (18.235941231250763%)
# MT_Uneven (17.609433829784393%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBLW001.jpg]:
# Top-1 (confidence)
# MT_Free (19.03248429298401%)
#
# With Transfer Learning [MTBLW001.jpg]:
# Top-1 (confidence)
# MT_Free (19.03248429298401%)
#
# Class (confidence)
# MT_Blowhole (17.353221774101257%)
# MT_Break (14.724993705749512%)
# MT_Crack (12.540830671787262%)
# MT_Fray (17.953351140022278%)
# MT_Free (19.03248429298401%)
# MT_Uneven (18.395116925239563%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBRK010.jpg]:
# Top-1 (confidence)
# MT_Free (18.404386937618256%)
#
# With Transfer Learning [MTBRK010.jpg]:
# Top-1 (confidence)
# MT_Free (18.404386937618256%)
#
# Class (confidence)
# MT_Blowhole (16.322430968284607%)
# MT_Break (14.660535752773285%)
# MT_Crack (13.897264003753662%)
# MT_Fray (18.34947168827057%)
# MT_Free (18.404386937618256%)
# MT_Uneven (18.36591064929962%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFREE028.jpg]:
# Top-1 (confidence)
# MT_Free (19.01857554912567%)
#
# With Transfer Learning [MTFREE028.jpg]:
# Top-1 (confidence)
# MT_Free (19.01857554912567%)
#
# Class (confidence)
# MT_Blowhole (16.47738218307495%)
# MT_Break (14.409074187278748%)
# MT_Crack (14.31458294391632%)
# MT_Fray (17.44789183139801%)
# MT_Free (19.01857554912567%)
# MT_Uneven (18.3324933052063%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTCRK011.jpg]:
# Top-1 (confidence)
# MT_Fray (18.810133635997772%)
#
# With Transfer Learning [MTCRK011.jpg]:
# Top-1 (confidence)
# MT_Fray (18.810133635997772%)
#
# Class (confidence)
# MT_Blowhole (16.883915662765503%)
# MT_Break (14.502820372581482%)
# MT_Crack (13.775818049907684%)
# MT_Fray (18.810133635997772%)
# MT_Free (17.582176625728607%)
# MT_Uneven (18.445131182670593%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFREE004.jpg]:
# Top-1 (confidence)
# MT_Uneven (19.40125674009323%)
#
# With Transfer Learning [MTFREE004.jpg]:
# Top-1 (confidence)
# MT_Uneven (19.40125674009323%)
#
# Class (confidence)
# MT_Blowhole (17.52774864435196%)
# MT_Break (14.037974178791046%)
# MT_Crack (13.548807799816132%)
# MT_Fray (17.86377727985382%)
# MT_Free (17.620444297790527%)
# MT_Uneven (19.40125674009323%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBRK018.jpg]:
# Top-1 (confidence)
# MT_Fray (18.463054299354553%)
#
# With Transfer Learning [MTBRK018.jpg]:
# Top-1 (confidence)
# MT_Fray (18.463054299354553%)
#
# Class (confidence)
# MT_Blowhole (17.088991403579712%)
# MT_Break (14.90895301103592%)
# MT_Crack (13.806432485580444%)
# MT_Fray (18.463054299354553%)
# MT_Free (18.320432305336%)
# MT_Uneven (17.412136495113373%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFREE013.jpg]:
# Top-1 (confidence)
# MT_Free (18.583552539348602%)
#
# With Transfer Learning [MTFREE013.jpg]:
# Top-1 (confidence)
# MT_Free (18.583552539348602%)
#
# Class (confidence)
# MT_Blowhole (16.745643317699432%)
# MT_Break (14.596502482891083%)
# MT_Crack (13.74499499797821%)
# MT_Fray (18.232595920562744%)
# MT_Free (18.583552539348602%)
# MT_Uneven (18.096713721752167%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBRK009.jpg]:
# Top-1 (confidence)
# MT_Uneven (18.98442953824997%)
#
# With Transfer Learning [MTBRK009.jpg]:
# Top-1 (confidence)
# MT_Uneven (18.98442953824997%)
#
# Class (confidence)
# MT_Blowhole (16.784295439720154%)
# MT_Break (14.593687653541565%)
# MT_Crack (12.96578049659729%)
# MT_Fray (18.78787875175476%)
# MT_Free (17.88392663002014%)
# MT_Uneven (18.98442953824997%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFRY001.jpg]:
# Top-1 (confidence)
# MT_Uneven (19.630329310894012%)
#
# With Transfer Learning [MTFRY001.jpg]:
# Top-1 (confidence)
# MT_Uneven (19.630329310894012%)
#
# Class (confidence)
# MT_Blowhole (17.296436429023743%)
# MT_Break (14.288678765296936%)
# MT_Crack (14.251135289669037%)
# MT_Fray (17.170944809913635%)
# MT_Free (17.362472414970398%)
# MT_Uneven (19.630329310894012%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBRK007.jpg]:
# Top-1 (confidence)
# MT_Fray (18.914581835269928%)
#
# With Transfer Learning [MTBRK007.jpg]:
# Top-1 (confidence)
# MT_Fray (18.914581835269928%)
#
# Class (confidence)
# MT_Blowhole (17.23490208387375%)
# MT_Break (14.441117644309998%)
# MT_Crack (13.999900221824646%)
# MT_Fray (18.914581835269928%)
# MT_Free (17.852871119976044%)
# MT_Uneven (17.556622624397278%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTUNEVEN021.jpg]:
# Top-1 (confidence)
# MT_Fray (18.66622120141983%)
#
# With Transfer Learning [MTUNEVEN021.jpg]:
# Top-1 (confidence)
# MT_Fray (18.66622120141983%)
#
# Class (confidence)
# MT_Blowhole (16.180028021335602%)
# MT_Break (14.981642365455627%)
# MT_Crack (14.20486569404602%)
# MT_Fray (18.66622120141983%)
# MT_Free (18.437811732292175%)
# MT_Uneven (17.529432475566864%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBLW003.jpg]:
# Top-1 (confidence)
# MT_Free (19.261863827705383%)
#
# With Transfer Learning [MTBLW003.jpg]:
# Top-1 (confidence)
# MT_Free (19.261863827705383%)
#
# Class (confidence)
# MT_Blowhole (17.926879227161407%)
# MT_Break (13.923244178295135%)
# MT_Crack (13.380907475948334%)
# MT_Fray (17.110399901866913%)
# MT_Free (19.261863827705383%)
# MT_Uneven (18.396705389022827%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFREE017.jpg]:
# Top-1 (confidence)
# MT_Free (18.75237375497818%)
#
# With Transfer Learning [MTFREE017.jpg]:
# Top-1 (confidence)
# MT_Free (18.75237375497818%)
#
# Class (confidence)
# MT_Blowhole (16.330109536647797%)
# MT_Break (14.869941771030426%)
# MT_Crack (13.744159042835236%)
# MT_Fray (18.66266280412674%)
# MT_Free (18.75237375497818%)
# MT_Uneven (17.640753090381622%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFREE021.jpg]:
# Top-1 (confidence)
# MT_Free (19.3588986992836%)
#
# With Transfer Learning [MTFREE021.jpg]:
# Top-1 (confidence)
# MT_Free (19.3588986992836%)
#
# Class (confidence)
# MT_Blowhole (15.991052985191345%)
# MT_Break (14.73013162612915%)
# MT_Crack (13.448402285575867%)
# MT_Fray (18.204985558986664%)
# MT_Free (19.3588986992836%)
# MT_Uneven (18.266528844833374%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBLW005.jpg]:
# Top-1 (confidence)
# MT_Free (18.460065126419067%)
#
# With Transfer Learning [MTBLW005.jpg]:
# Top-1 (confidence)
# MT_Free (18.460065126419067%)
#
# Class (confidence)
# MT_Blowhole (17.474371194839478%)
# MT_Break (14.910104870796204%)
# MT_Crack (13.175594806671143%)
# MT_Fray (18.26505959033966%)
# MT_Free (18.460065126419067%)
# MT_Uneven (17.714811861515045%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBRK005.jpg]:
# Top-1 (confidence)
# MT_Free (18.91304701566696%)
#
# With Transfer Learning [MTBRK005.jpg]:
# Top-1 (confidence)
# MT_Free (18.91304701566696%)
#
# Class (confidence)
# MT_Blowhole (16.415654122829437%)
# MT_Break (15.063382685184479%)
# MT_Crack (13.171246647834778%)
# MT_Fray (18.381880223751068%)
# MT_Free (18.91304701566696%)
# MT_Uneven (18.054792284965515%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTUNEVEN006.jpg]:
# Top-1 (confidence)
# MT_Fray (20.115390419960022%)
#
# With Transfer Learning [MTUNEVEN006.jpg]:
# Top-1 (confidence)
# MT_Fray (20.115390419960022%)
#
# Class (confidence)
# MT_Blowhole (16.516810655593872%)
# MT_Break (15.096348524093628%)
# MT_Crack (13.694065809249878%)
# MT_Fray (20.115390419960022%)
# MT_Free (17.830049991607666%)
# MT_Uneven (16.747334599494934%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBLW012.jpg]:
# Top-1 (confidence)
# MT_Fray (18.818730115890503%)
#
# With Transfer Learning [MTBLW012.jpg]:
# Top-1 (confidence)
# MT_Fray (18.818730115890503%)
#
# Class (confidence)
# MT_Blowhole (16.69394075870514%)
# MT_Break (14.558844268321991%)
# MT_Crack (13.639380037784576%)
# MT_Fray (18.818730115890503%)
# MT_Free (18.66787075996399%)
# MT_Uneven (17.62123554944992%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFREE022.jpg]:
# Top-1 (confidence)
# MT_Free (19.062647223472595%)
#
# With Transfer Learning [MTFREE022.jpg]:
# Top-1 (confidence)
# MT_Free (19.062647223472595%)
#
# Class (confidence)
# MT_Blowhole (16.43121838569641%)
# MT_Break (14.824327826499939%)
# MT_Crack (13.32034021615982%)
# MT_Fray (18.335719406604767%)
# MT_Free (19.062647223472595%)
# MT_Uneven (18.025745451450348%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFRY009.jpg]:
# Top-1 (confidence)
# MT_Free (19.021345674991608%)
#
# With Transfer Learning [MTFRY009.jpg]:
# Top-1 (confidence)
# MT_Free (19.021345674991608%)
#
# Class (confidence)
# MT_Blowhole (15.994653105735779%)
# MT_Break (14.535745978355408%)
# MT_Crack (13.55828195810318%)
# MT_Fray (18.3831587433815%)
# MT_Free (19.021345674991608%)
# MT_Uneven (18.506811559200287%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBRK017.jpg]:
# Top-1 (confidence)
# MT_Fray (19.02453750371933%)
#
# With Transfer Learning [MTBRK017.jpg]:
# Top-1 (confidence)
# MT_Fray (19.02453750371933%)
#
# Class (confidence)
# MT_Blowhole (16.549232602119446%)
# MT_Break (14.700549840927124%)
# MT_Crack (13.44805359840393%)
# MT_Fray (19.02453750371933%)
# MT_Free (18.56626719236374%)
# MT_Uneven (17.71135777235031%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTUNEVEN007.jpg]:
# Top-1 (confidence)
# MT_Free (18.960443139076233%)
#
# With Transfer Learning [MTUNEVEN007.jpg]:
# Top-1 (confidence)
# MT_Free (18.960443139076233%)
#
# Class (confidence)
# MT_Blowhole (16.08331799507141%)
# MT_Break (15.054886043071747%)
# MT_Crack (13.43451738357544%)
# MT_Fray (17.9883673787117%)
# MT_Free (18.960443139076233%)
# MT_Uneven (18.47846806049347%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTUNEVEN010.jpg]:
# Top-1 (confidence)
# MT_Free (18.54003220796585%)
#
# With Transfer Learning [MTUNEVEN010.jpg]:
# Top-1 (confidence)
# MT_Free (18.54003220796585%)
#
# Class (confidence)
# MT_Blowhole (16.050156950950623%)
# MT_Break (14.838562905788422%)
# MT_Crack (14.067815244197845%)
# MT_Fray (18.452470004558563%)
# MT_Free (18.54003220796585%)
# MT_Uneven (18.050959706306458%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFRY004.jpg]:
# Top-1 (confidence)
# MT_Uneven (19.110557436943054%)
#
# With Transfer Learning [MTFRY004.jpg]:
# Top-1 (confidence)
# MT_Uneven (19.110557436943054%)
#
# Class (confidence)
# MT_Blowhole (16.75875186920166%)
# MT_Break (14.034180343151093%)
# MT_Crack (13.596442341804504%)
# MT_Fray (18.226082623004913%)
# MT_Free (18.273986876010895%)
# MT_Uneven (19.110557436943054%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFREE008.jpg]:
# Top-1 (confidence)
# MT_Uneven (18.60535740852356%)
#
# With Transfer Learning [MTFREE008.jpg]:
# Top-1 (confidence)
# MT_Uneven (18.60535740852356%)
#
# Class (confidence)
# MT_Blowhole (17.102037370204926%)
# MT_Break (14.387576282024384%)
# MT_Crack (13.311512768268585%)
# MT_Fray (18.483252823352814%)
# MT_Free (18.110260367393494%)
# MT_Uneven (18.60535740852356%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFREE020.jpg]:
# Top-1 (confidence)
# MT_Free (18.67806315422058%)
#
# With Transfer Learning [MTFREE020.jpg]:
# Top-1 (confidence)
# MT_Free (18.67806315422058%)
#
# Class (confidence)
# MT_Blowhole (16.532234847545624%)
# MT_Break (14.426393806934357%)
# MT_Crack (14.063350856304169%)
# MT_Fray (17.954730987548828%)
# MT_Free (18.67806315422058%)
# MT_Uneven (18.345224857330322%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBRK004.jpg]:
# Top-1 (confidence)
# MT_Free (18.889562785625458%)
#
# With Transfer Learning [MTBRK004.jpg]:
# Top-1 (confidence)
# MT_Free (18.889562785625458%)
#
# Class (confidence)
# MT_Blowhole (17.018921673297882%)
# MT_Break (14.362755417823792%)
# MT_Crack (14.392141997814178%)
# MT_Fray (17.49359965324402%)
# MT_Free (18.889562785625458%)
# MT_Uneven (17.84301847219467%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTCRK008.jpg]:
# Top-1 (confidence)
# MT_Free (19.254423677921295%)
#
# With Transfer Learning [MTCRK008.jpg]:
# Top-1 (confidence)
# MT_Free (19.254423677921295%)
#
# Class (confidence)
# MT_Blowhole (16.417211294174194%)
# MT_Break (14.50493037700653%)
# MT_Crack (13.56724202632904%)
# MT_Fray (18.01205277442932%)
# MT_Free (19.254423677921295%)
# MT_Uneven (18.244139850139618%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBLW006.jpg]:
# Top-1 (confidence)
# MT_Free (19.46234703063965%)
#
# With Transfer Learning [MTBLW006.jpg]:
# Top-1 (confidence)
# MT_Free (19.46234703063965%)
#
# Class (confidence)
# MT_Blowhole (16.968858242034912%)
# MT_Break (15.135082602500916%)
# MT_Crack (13.32201361656189%)
# MT_Fray (17.786574363708496%)
# MT_Free (19.46234703063965%)
# MT_Uneven (17.325127124786377%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFREE005.jpg]:
# Top-1 (confidence)
# MT_Free (18.871161341667175%)
#
# With Transfer Learning [MTFREE005.jpg]:
# Top-1 (confidence)
# MT_Free (18.871161341667175%)
#
# Class (confidence)
# MT_Blowhole (16.83352142572403%)
# MT_Break (14.596891403198242%)
# MT_Crack (13.748809695243835%)
# MT_Fray (18.379533290863037%)
# MT_Free (18.871161341667175%)
# MT_Uneven (17.57008135318756%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFREE026.jpg]:
# Top-1 (confidence)
# MT_Free (18.77976655960083%)
#
# With Transfer Learning [MTFREE026.jpg]:
# Top-1 (confidence)
# MT_Free (18.77976655960083%)
#
# Class (confidence)
# MT_Blowhole (16.48891568183899%)
# MT_Break (14.851850271224976%)
# MT_Crack (13.593879342079163%)
# MT_Fray (18.398556113243103%)
# MT_Free (18.77976655960083%)
# MT_Uneven (17.887026071548462%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBRK016.jpg]:
# Top-1 (confidence)
# MT_Uneven (19.40784901380539%)
#
# With Transfer Learning [MTBRK016.jpg]:
# Top-1 (confidence)
# MT_Uneven (19.40784901380539%)
#
# Class (confidence)
# MT_Blowhole (17.407894134521484%)
# MT_Break (14.454573392868042%)
# MT_Crack (13.259680569171906%)
# MT_Fray (17.545591294765472%)
# MT_Free (17.924410104751587%)
# MT_Uneven (19.40784901380539%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBRK011.jpg]:
# Top-1 (confidence)
# MT_Fray (18.42128038406372%)
#
# With Transfer Learning [MTBRK011.jpg]:
# Top-1 (confidence)
# MT_Fray (18.42128038406372%)
#
# Class (confidence)
# MT_Blowhole (17.647631466388702%)
# MT_Break (14.879950881004333%)
# MT_Crack (13.484422862529755%)
# MT_Fray (18.42128038406372%)
# MT_Free (17.76895523071289%)
# MT_Uneven (17.797762155532837%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTUNEVEN008.jpg]:
# Top-1 (confidence)
# MT_Uneven (19.000816345214844%)
#
# With Transfer Learning [MTUNEVEN008.jpg]:
# Top-1 (confidence)
# MT_Uneven (19.000816345214844%)
#
# Class (confidence)
# MT_Blowhole (16.307508945465088%)
# MT_Break (14.325211942195892%)
# MT_Crack (13.623328506946564%)
# MT_Fray (18.035462498664856%)
# MT_Free (18.707670271396637%)
# MT_Uneven (19.000816345214844%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTCRK016.jpg]:
# Top-1 (confidence)
# MT_Fray (18.587860465049744%)
#
# With Transfer Learning [MTCRK016.jpg]:
# Top-1 (confidence)
# MT_Fray (18.587860465049744%)
#
# Class (confidence)
# MT_Blowhole (16.74542725086212%)
# MT_Break (14.715142548084259%)
# MT_Crack (13.912288844585419%)
# MT_Fray (18.587860465049744%)
# MT_Free (18.36252510547638%)
# MT_Uneven (17.67675280570984%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTCRK010.jpg]:
# Top-1 (confidence)
# MT_Fray (18.964822590351105%)
#
# With Transfer Learning [MTCRK010.jpg]:
# Top-1 (confidence)
# MT_Fray (18.964822590351105%)
#
# Class (confidence)
# MT_Blowhole (16.943947970867157%)
# MT_Break (14.98798131942749%)
# MT_Crack (13.22651356458664%)
# MT_Fray (18.964822590351105%)
# MT_Free (18.518657982349396%)
# MT_Uneven (17.358076572418213%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFREE025.jpg]:
# Top-1 (confidence)
# MT_Free (18.86824369430542%)
#
# With Transfer Learning [MTFREE025.jpg]:
# Top-1 (confidence)
# MT_Free (18.86824369430542%)
#
# Class (confidence)
# MT_Blowhole (16.950862109661102%)
# MT_Break (14.950846135616302%)
# MT_Crack (13.406676054000854%)
# MT_Fray (18.00220012664795%)
# MT_Free (18.86824369430542%)
# MT_Uneven (17.821165919303894%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFREE010.jpg]:
# Top-1 (confidence)
# MT_Free (18.703369796276093%)
#
# With Transfer Learning [MTFREE010.jpg]:
# Top-1 (confidence)
# MT_Free (18.703369796276093%)
#
# Class (confidence)
# MT_Blowhole (16.742415726184845%)
# MT_Break (14.65218961238861%)
# MT_Crack (13.772715628147125%)
# MT_Fray (18.352361023426056%)
# MT_Free (18.703369796276093%)
# MT_Uneven (17.776942253112793%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTCRK017.jpg]:
# Top-1 (confidence)
# MT_Free (18.78729909658432%)
#
# With Transfer Learning [MTCRK017.jpg]:
# Top-1 (confidence)
# MT_Free (18.78729909658432%)
#
# Class (confidence)
# MT_Blowhole (17.205806076526642%)
# MT_Break (14.910991489887238%)
# MT_Crack (13.347461819648743%)
# MT_Fray (18.20295602083206%)
# MT_Free (18.78729909658432%)
# MT_Uneven (17.545488476753235%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBRK012.jpg]:
# Top-1 (confidence)
# MT_Free (19.084258377552032%)
#
# With Transfer Learning [MTBRK012.jpg]:
# Top-1 (confidence)
# MT_Free (19.084258377552032%)
#
# Class (confidence)
# MT_Blowhole (17.692352831363678%)
# MT_Break (14.600996673107147%)
# MT_Crack (13.535724580287933%)
# MT_Fray (17.331895232200623%)
# MT_Free (19.084258377552032%)
# MT_Uneven (17.754775285720825%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTUNEVEN003.jpg]:
# Top-1 (confidence)
# MT_Free (19.30636465549469%)
#
# With Transfer Learning [MTUNEVEN003.jpg]:
# Top-1 (confidence)
# MT_Free (19.30636465549469%)
#
# Class (confidence)
# MT_Blowhole (16.611239314079285%)
# MT_Break (14.49602097272873%)
# MT_Crack (14.147312939167023%)
# MT_Fray (18.290413916110992%)
# MT_Free (19.30636465549469%)
# MT_Uneven (17.148642241954803%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTUNEVEN012.jpg]:
# Top-1 (confidence)
# MT_Free (19.24179047346115%)
#
# With Transfer Learning [MTUNEVEN012.jpg]:
# Top-1 (confidence)
# MT_Free (19.24179047346115%)
#
# Class (confidence)
# MT_Blowhole (16.83674305677414%)
# MT_Break (14.434367418289185%)
# MT_Crack (13.056443631649017%)
# MT_Fray (17.82708913087845%)
# MT_Free (19.24179047346115%)
# MT_Uneven (18.60356479883194%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFREE003.jpg]:
# Top-1 (confidence)
# MT_Uneven (18.550173938274384%)
#
# With Transfer Learning [MTFREE003.jpg]:
# Top-1 (confidence)
# MT_Uneven (18.550173938274384%)
#
# Class (confidence)
# MT_Blowhole (17.045240104198456%)
# MT_Break (14.449666440486908%)
# MT_Crack (13.559217751026154%)
# MT_Fray (17.99198091030121%)
# MT_Free (18.40372234582901%)
# MT_Uneven (18.550173938274384%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTCRK005.jpg]:
# Top-1 (confidence)
# MT_Free (18.542808294296265%)
#
# With Transfer Learning [MTCRK005.jpg]:
# Top-1 (confidence)
# MT_Free (18.542808294296265%)
#
# Class (confidence)
# MT_Blowhole (17.46666729450226%)
# MT_Break (14.887972176074982%)
# MT_Crack (13.084225356578827%)
# MT_Fray (18.22127252817154%)
# MT_Free (18.542808294296265%)
# MT_Uneven (17.79704988002777%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBLW010.jpg]:
# Top-1 (confidence)
# MT_Fray (18.38778555393219%)
#
# With Transfer Learning [MTBLW010.jpg]:
# Top-1 (confidence)
# MT_Fray (18.38778555393219%)
#
# Class (confidence)
# MT_Blowhole (16.96220338344574%)
# MT_Break (14.567328989505768%)
# MT_Crack (13.664299249649048%)
# MT_Fray (18.38778555393219%)
# MT_Free (18.161875009536743%)
# MT_Uneven (18.256506323814392%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBLW016.jpg]:
# Top-1 (confidence)
# MT_Free (18.639017641544342%)
#
# With Transfer Learning [MTBLW016.jpg]:
# Top-1 (confidence)
# MT_Free (18.639017641544342%)
#
# Class (confidence)
# MT_Blowhole (16.364990174770355%)
# MT_Break (14.492228627204895%)
# MT_Crack (13.95249217748642%)
# MT_Fray (18.37441623210907%)
# MT_Free (18.639017641544342%)
# MT_Uneven (18.17685067653656%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTCRK014.jpg]:
# Top-1 (confidence)
# MT_Free (19.14152503013611%)
#
# With Transfer Learning [MTCRK014.jpg]:
# Top-1 (confidence)
# MT_Free (19.14152503013611%)
#
# Class (confidence)
# MT_Blowhole (16.255150735378265%)
# MT_Break (14.709150791168213%)
# MT_Crack (13.200441002845764%)
# MT_Fray (17.799663543701172%)
# MT_Free (19.14152503013611%)
# MT_Uneven (18.894062936306%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBLW015.jpg]:
# Top-1 (confidence)
# MT_Free (19.252152740955353%)
#
# With Transfer Learning [MTBLW015.jpg]:
# Top-1 (confidence)
# MT_Free (19.252152740955353%)
#
# Class (confidence)
# MT_Blowhole (16.732634603977203%)
# MT_Break (14.896145462989807%)
# MT_Crack (13.525554537773132%)
# MT_Fray (18.07103604078293%)
# MT_Free (19.252152740955353%)
# MT_Uneven (17.522473633289337%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFREE023.jpg]:
# Top-1 (confidence)
# MT_Free (18.365706503391266%)
#
# With Transfer Learning [MTFREE023.jpg]:
# Top-1 (confidence)
# MT_Free (18.365706503391266%)
#
# Class (confidence)
# MT_Blowhole (17.285853624343872%)
# MT_Break (14.231812953948975%)
# MT_Crack (14.3608957529068%)
# MT_Fray (17.842192947864532%)
# MT_Free (18.365706503391266%)
# MT_Uneven (17.913536727428436%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBRK014.jpg]:
# Top-1 (confidence)
# MT_Fray (18.121974170207977%)
#
# With Transfer Learning [MTBRK014.jpg]:
# Top-1 (confidence)
# MT_Fray (18.121974170207977%)
#
# Class (confidence)
# MT_Blowhole (17.917709052562714%)
# MT_Break (14.983882009983063%)
# MT_Crack (13.352464139461517%)
# MT_Fray (18.121974170207977%)
# MT_Free (17.95726716518402%)
# MT_Uneven (17.666710913181305%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTUNEVEN017.jpg]:
# Top-1 (confidence)
# MT_Fray (19.339923560619354%)
#
# With Transfer Learning [MTUNEVEN017.jpg]:
# Top-1 (confidence)
# MT_Fray (19.339923560619354%)
#
# Class (confidence)
# MT_Blowhole (17.49614030122757%)
# MT_Break (15.094636380672455%)
# MT_Crack (12.975043058395386%)
# MT_Fray (19.339923560619354%)
# MT_Free (17.908796668052673%)
# MT_Uneven (17.18546152114868%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFRY008.jpg]:
# Top-1 (confidence)
# MT_Uneven (18.785998225212097%)
#
# With Transfer Learning [MTFRY008.jpg]:
# Top-1 (confidence)
# MT_Uneven (18.785998225212097%)
#
# Class (confidence)
# MT_Blowhole (17.379717528820038%)
# MT_Break (14.715690910816193%)
# MT_Crack (13.575370609760284%)
# MT_Fray (17.600663006305695%)
# MT_Free (17.942556738853455%)
# MT_Uneven (18.785998225212097%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTCRK009.jpg]:
# Top-1 (confidence)
# MT_Fray (18.42493563890457%)
#
# With Transfer Learning [MTCRK009.jpg]:
# Top-1 (confidence)
# MT_Fray (18.42493563890457%)
#
# Class (confidence)
# MT_Blowhole (16.985410451889038%)
# MT_Break (14.990493655204773%)
# MT_Crack (13.32956999540329%)
# MT_Fray (18.42493563890457%)
# MT_Free (18.3326855301857%)
# MT_Uneven (17.936894297599792%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBLW014.jpg]:
# Top-1 (confidence)
# MT_Free (19.54435259103775%)
#
# With Transfer Learning [MTBLW014.jpg]:
# Top-1 (confidence)
# MT_Free (19.54435259103775%)
#
# Class (confidence)
# MT_Blowhole (16.331978142261505%)
# MT_Break (14.421208202838898%)
# MT_Crack (13.770227134227753%)
# MT_Fray (18.15630793571472%)
# MT_Free (19.54435259103775%)
# MT_Uneven (17.775927484035492%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTUNEVEN020.jpg]:
# Top-1 (confidence)
# MT_Free (19.1607803106308%)
#
# With Transfer Learning [MTUNEVEN020.jpg]:
# Top-1 (confidence)
# MT_Free (19.1607803106308%)
#
# Class (confidence)
# MT_Blowhole (16.066132485866547%)
# MT_Break (14.519976079463959%)
# MT_Crack (13.963384926319122%)
# MT_Fray (18.900233507156372%)
# MT_Free (19.1607803106308%)
# MT_Uneven (17.389489710330963%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFRY003.jpg]:
# Top-1 (confidence)
# MT_Free (19.34579908847809%)
#
# With Transfer Learning [MTFRY003.jpg]:
# Top-1 (confidence)
# MT_Free (19.34579908847809%)
#
# Class (confidence)
# MT_Blowhole (16.048745810985565%)
# MT_Break (14.295564591884613%)
# MT_Crack (13.396723568439484%)
# MT_Fray (18.243616819381714%)
# MT_Free (19.34579908847809%)
# MT_Uneven (18.669550120830536%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFRY006.jpg]:
# Top-1 (confidence)
# MT_Free (19.16401833295822%)
#
# With Transfer Learning [MTFRY006.jpg]:
# Top-1 (confidence)
# MT_Free (19.16401833295822%)
#
# Class (confidence)
# MT_Blowhole (16.857196390628815%)
# MT_Break (14.816886186599731%)
# MT_Crack (13.072387874126434%)
# MT_Fray (18.180526793003082%)
# MT_Free (19.16401833295822%)
# MT_Uneven (17.908990383148193%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFREE006.jpg]:
# Top-1 (confidence)
# MT_Uneven (18.318170309066772%)
#
# With Transfer Learning [MTFREE006.jpg]:
# Top-1 (confidence)
# MT_Uneven (18.318170309066772%)
#
# Class (confidence)
# MT_Blowhole (16.89039021730423%)
# MT_Break (14.794202148914337%)
# MT_Crack (13.591775298118591%)
# MT_Fray (18.118616938591003%)
# MT_Free (18.286846578121185%)
# MT_Uneven (18.318170309066772%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBLW009.jpg]:
# Top-1 (confidence)
# MT_Fray (18.7865749001503%)
#
# With Transfer Learning [MTBLW009.jpg]:
# Top-1 (confidence)
# MT_Fray (18.7865749001503%)
#
# Class (confidence)
# MT_Blowhole (18.023625016212463%)
# MT_Break (14.470651745796204%)
# MT_Crack (13.609391450881958%)
# MT_Fray (18.7865749001503%)
# MT_Free (16.879166662693024%)
# MT_Uneven (18.230590224266052%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTCRK013.jpg]:
# Top-1 (confidence)
# MT_Uneven (19.20762211084366%)
#
# With Transfer Learning [MTCRK013.jpg]:
# Top-1 (confidence)
# MT_Uneven (19.20762211084366%)
#
# Class (confidence)
# MT_Blowhole (16.12205058336258%)
# MT_Break (14.493471384048462%)
# MT_Crack (12.98074722290039%)
# MT_Fray (18.137332797050476%)
# MT_Free (19.058775901794434%)
# MT_Uneven (19.20762211084366%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTCRK003.jpg]:
# Top-1 (confidence)
# MT_Uneven (19.37652975320816%)
#
# With Transfer Learning [MTCRK003.jpg]:
# Top-1 (confidence)
# MT_Uneven (19.37652975320816%)
#
# Class (confidence)
# MT_Blowhole (16.120634973049164%)
# MT_Break (14.264944195747375%)
# MT_Crack (13.13747763633728%)
# MT_Fray (17.802031338214874%)
# MT_Free (19.298376142978668%)
# MT_Uneven (19.37652975320816%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBRK019.jpg]:
# Top-1 (confidence)
# MT_Free (18.844246864318848%)
#
# With Transfer Learning [MTBRK019.jpg]:
# Top-1 (confidence)
# MT_Free (18.844246864318848%)
#
# Class (confidence)
# MT_Blowhole (16.97646528482437%)
# MT_Break (14.173701405525208%)
# MT_Crack (14.496105909347534%)
# MT_Fray (17.265307903289795%)
# MT_Free (18.844246864318848%)
# MT_Uneven (18.244168162345886%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTUNEVEN015.jpg]:
# Top-1 (confidence)
# MT_Fray (18.285901844501495%)
#
# With Transfer Learning [MTUNEVEN015.jpg]:
# Top-1 (confidence)
# MT_Fray (18.285901844501495%)
#
# Class (confidence)
# MT_Blowhole (17.794114351272583%)
# MT_Break (14.690302312374115%)
# MT_Crack (13.476252555847168%)
# MT_Fray (18.285901844501495%)
# MT_Free (18.006807565689087%)
# MT_Uneven (17.746616899967194%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBRK003.jpg]:
# Top-1 (confidence)
# MT_Free (18.28228086233139%)
#
# With Transfer Learning [MTBRK003.jpg]:
# Top-1 (confidence)
# MT_Free (18.28228086233139%)
#
# Class (confidence)
# MT_Blowhole (17.335432767868042%)
# MT_Break (14.323090016841888%)
# MT_Crack (14.393490552902222%)
# MT_Fray (17.713209986686707%)
# MT_Free (18.28228086233139%)
# MT_Uneven (17.952491343021393%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFREE001.jpg]:
# Top-1 (confidence)
# MT_Free (18.383315205574036%)
#
# With Transfer Learning [MTFREE001.jpg]:
# Top-1 (confidence)
# MT_Free (18.383315205574036%)
#
# Class (confidence)
# MT_Blowhole (17.57865697145462%)
# MT_Break (13.954231142997742%)
# MT_Crack (13.563832640647888%)
# MT_Fray (18.30544024705887%)
# MT_Free (18.383315205574036%)
# MT_Uneven (18.214523792266846%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTUNEVEN014.jpg]:
# Top-1 (confidence)
# MT_Free (19.213543832302094%)
#
# With Transfer Learning [MTUNEVEN014.jpg]:
# Top-1 (confidence)
# MT_Free (19.213543832302094%)
#
# Class (confidence)
# MT_Blowhole (16.364550590515137%)
# MT_Break (14.471307396888733%)
# MT_Crack (13.714472949504852%)
# MT_Fray (17.911066114902496%)
# MT_Free (19.213543832302094%)
# MT_Uneven (18.32505613565445%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBRK015.jpg]:
# Top-1 (confidence)
# MT_Uneven (18.28182488679886%)
#
# With Transfer Learning [MTBRK015.jpg]:
# Top-1 (confidence)
# MT_Uneven (18.28182488679886%)
#
# Class (confidence)
# MT_Blowhole (18.265120685100555%)
# MT_Break (14.858385920524597%)
# MT_Crack (14.131705462932587%)
# MT_Fray (16.204476356506348%)
# MT_Free (18.258488178253174%)
# MT_Uneven (18.28182488679886%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFRY005.jpg]:
# Top-1 (confidence)
# MT_Uneven (19.502148032188416%)
#
# With Transfer Learning [MTFRY005.jpg]:
# Top-1 (confidence)
# MT_Uneven (19.502148032188416%)
#
# Class (confidence)
# MT_Blowhole (16.882500052452087%)
# MT_Break (14.077112078666687%)
# MT_Crack (14.720414578914642%)
# MT_Fray (17.399635910987854%)
# MT_Free (17.418193817138672%)
# MT_Uneven (19.502148032188416%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBRK006.jpg]:
# Top-1 (confidence)
# MT_Fray (18.432359397411346%)
#
# With Transfer Learning [MTBRK006.jpg]:
# Top-1 (confidence)
# MT_Fray (18.432359397411346%)
#
# Class (confidence)
# MT_Blowhole (17.51411408185959%)
# MT_Break (15.056656301021576%)
# MT_Crack (14.175491034984589%)
# MT_Fray (18.432359397411346%)
# MT_Free (17.154963314533234%)
# MT_Uneven (17.666418850421906%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBRK002.jpg]:
# Top-1 (confidence)
# MT_Uneven (18.381206691265106%)
#
# With Transfer Learning [MTBRK002.jpg]:
# Top-1 (confidence)
# MT_Uneven (18.381206691265106%)
#
# Class (confidence)
# MT_Blowhole (16.767317056655884%)
# MT_Break (15.143218636512756%)
# MT_Crack (13.393376767635345%)
# MT_Fray (17.940738797187805%)
# MT_Free (18.374137580394745%)
# MT_Uneven (18.381206691265106%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFREE009.jpg]:
# Top-1 (confidence)
# MT_Free (18.244080245494843%)
#
# With Transfer Learning [MTFREE009.jpg]:
# Top-1 (confidence)
# MT_Free (18.244080245494843%)
#
# Class (confidence)
# MT_Blowhole (17.120788991451263%)
# MT_Break (14.496906101703644%)
# MT_Crack (14.20210599899292%)
# MT_Fray (17.76037961244583%)
# MT_Free (18.244080245494843%)
# MT_Uneven (18.17573308944702%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFREE016.jpg]:
# Top-1 (confidence)
# MT_Free (18.729642033576965%)
#
# With Transfer Learning [MTFREE016.jpg]:
# Top-1 (confidence)
# MT_Free (18.729642033576965%)
#
# Class (confidence)
# MT_Blowhole (16.46347939968109%)
# MT_Break (14.340826869010925%)
# MT_Crack (14.022687077522278%)
# MT_Fray (18.086479604244232%)
# MT_Free (18.729642033576965%)
# MT_Uneven (18.356885015964508%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFREE012.jpg]:
# Top-1 (confidence)
# MT_Uneven (18.70753765106201%)
#
# With Transfer Learning [MTFREE012.jpg]:
# Top-1 (confidence)
# MT_Uneven (18.70753765106201%)
#
# Class (confidence)
# MT_Blowhole (17.089590430259705%)
# MT_Break (14.326022565364838%)
# MT_Crack (13.431449234485626%)
# MT_Fray (18.190032243728638%)
# MT_Free (18.255366384983063%)
# MT_Uneven (18.70753765106201%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTCRK002.jpg]:
# Top-1 (confidence)
# MT_Free (19.36715990304947%)
#
# With Transfer Learning [MTCRK002.jpg]:
# Top-1 (confidence)
# MT_Free (19.36715990304947%)
#
# Class (confidence)
# MT_Blowhole (15.962409973144531%)
# MT_Break (14.295430481433868%)
# MT_Crack (13.072647154331207%)
# MT_Fray (17.948584258556366%)
# MT_Free (19.36715990304947%)
# MT_Uneven (19.353769719600677%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBLW002.jpg]:
# Top-1 (confidence)
# MT_Free (18.58191192150116%)
#
# With Transfer Learning [MTBLW002.jpg]:
# Top-1 (confidence)
# MT_Free (18.58191192150116%)
#
# Class (confidence)
# MT_Blowhole (16.73019528388977%)
# MT_Break (14.240114390850067%)
# MT_Crack (14.034603536128998%)
# MT_Fray (18.261180818080902%)
# MT_Free (18.58191192150116%)
# MT_Uneven (18.1520015001297%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFREE002.jpg]:
# Top-1 (confidence)
# MT_Free (19.088146090507507%)
#
# With Transfer Learning [MTFREE002.jpg]:
# Top-1 (confidence)
# MT_Free (19.088146090507507%)
#
# Class (confidence)
# MT_Blowhole (16.516190767288208%)
# MT_Break (14.194677770137787%)
# MT_Crack (13.792923092842102%)
# MT_Fray (17.765623331069946%)
# MT_Free (19.088146090507507%)
# MT_Uneven (18.642432987689972%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBLW013.jpg]:
# Top-1 (confidence)
# MT_Free (18.73672306537628%)
#
# With Transfer Learning [MTBLW013.jpg]:
# Top-1 (confidence)
# MT_Free (18.73672306537628%)
#
# Class (confidence)
# MT_Blowhole (17.994379997253418%)
# MT_Break (14.927691221237183%)
# MT_Crack (13.14186304807663%)
# MT_Fray (17.755691707134247%)
# MT_Free (18.73672306537628%)
# MT_Uneven (17.44365096092224%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTUNEVEN018.jpg]:
# Top-1 (confidence)
# MT_Free (18.834325671195984%)
#
# With Transfer Learning [MTUNEVEN018.jpg]:
# Top-1 (confidence)
# MT_Free (18.834325671195984%)
#
# Class (confidence)
# MT_Blowhole (16.752974689006805%)
# MT_Break (14.929890632629395%)
# MT_Crack (13.709406554698944%)
# MT_Fray (18.12520921230316%)
# MT_Free (18.834325671195984%)
# MT_Uneven (17.648188769817352%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFRY010.jpg]:
# Top-1 (confidence)
# MT_Fray (18.878574669361115%)
#
# With Transfer Learning [MTFRY010.jpg]:
# Top-1 (confidence)
# MT_Fray (18.878574669361115%)
#
# Class (confidence)
# MT_Blowhole (16.263678669929504%)
# MT_Break (14.103062450885773%)
# MT_Crack (14.326132833957672%)
# MT_Fray (18.878574669361115%)
# MT_Free (17.805364727973938%)
# MT_Uneven (18.62318068742752%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFREE014.jpg]:
# Top-1 (confidence)
# MT_Uneven (18.219678103923798%)
#
# With Transfer Learning [MTFREE014.jpg]:
# Top-1 (confidence)
# MT_Uneven (18.219678103923798%)
#
# Class (confidence)
# MT_Blowhole (17.55090057849884%)
# MT_Break (14.884139597415924%)
# MT_Crack (13.318054378032684%)
# MT_Fray (18.19237619638443%)
# MT_Free (17.834849655628204%)
# MT_Uneven (18.219678103923798%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTCRK012.jpg]:
# Top-1 (confidence)
# MT_Uneven (19.205409288406372%)
#
# With Transfer Learning [MTCRK012.jpg]:
# Top-1 (confidence)
# MT_Uneven (19.205409288406372%)
#
# Class (confidence)
# MT_Blowhole (16.17024540901184%)
# MT_Break (14.484402537345886%)
# MT_Crack (13.077947497367859%)
# MT_Fray (18.062901496887207%)
# MT_Free (18.999089300632477%)
# MT_Uneven (19.205409288406372%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFRY007.jpg]:
# Top-1 (confidence)
# MT_Blowhole (18.758799135684967%)
#
# With Transfer Learning [MTFRY007.jpg]:
# Top-1 (confidence)
# MT_Blowhole (18.758799135684967%)
#
# Class (confidence)
# MT_Blowhole (18.758799135684967%)
# MT_Break (13.333563506603241%)
# MT_Crack (15.194141864776611%)
# MT_Fray (18.470729887485504%)
# MT_Free (16.922232508659363%)
# MT_Uneven (17.320533096790314%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFREE015.jpg]:
# Top-1 (confidence)
# MT_Uneven (19.11686509847641%)
#
# With Transfer Learning [MTFREE015.jpg]:
# Top-1 (confidence)
# MT_Uneven (19.11686509847641%)
#
# Class (confidence)
# MT_Blowhole (16.981500387191772%)
# MT_Break (14.521750807762146%)
# MT_Crack (13.350409269332886%)
# MT_Fray (17.85958856344223%)
# MT_Free (18.169885873794556%)
# MT_Uneven (19.11686509847641%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBLW011.jpg]:
# Top-1 (confidence)
# MT_Free (19.280768930912018%)
#
# With Transfer Learning [MTBLW011.jpg]:
# Top-1 (confidence)
# MT_Free (19.280768930912018%)
#
# Class (confidence)
# MT_Blowhole (16.404879093170166%)
# MT_Break (14.605431258678436%)
# MT_Crack (13.660068809986115%)
# MT_Fray (18.16261112689972%)
# MT_Free (19.280768930912018%)
# MT_Uneven (17.886242270469666%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTCRK007.jpg]:
# Top-1 (confidence)
# MT_Fray (18.77093017101288%)
#
# With Transfer Learning [MTCRK007.jpg]:
# Top-1 (confidence)
# MT_Fray (18.77093017101288%)
#
# Class (confidence)
# MT_Blowhole (17.38644391298294%)
# MT_Break (14.91902619600296%)
# MT_Crack (13.226105272769928%)
# MT_Fray (18.77093017101288%)
# MT_Free (18.531979620456696%)
# MT_Uneven (17.165513336658478%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBRK001.jpg]:
# Top-1 (confidence)
# MT_Uneven (19.153712689876556%)
#
# With Transfer Learning [MTBRK001.jpg]:
# Top-1 (confidence)
# MT_Uneven (19.153712689876556%)
#
# Class (confidence)
# MT_Blowhole (17.630554735660553%)
# MT_Break (14.606611430644989%)
# MT_Crack (13.379533588886261%)
# MT_Fray (17.370183765888214%)
# MT_Free (17.85939782857895%)
# MT_Uneven (19.153712689876556%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFREE007.jpg]:
# Top-1 (confidence)
# MT_Fray (18.309475481510162%)
#
# With Transfer Learning [MTFREE007.jpg]:
# Top-1 (confidence)
# MT_Fray (18.309475481510162%)
#
# Class (confidence)
# MT_Blowhole (17.65565425157547%)
# MT_Break (14.414554834365845%)
# MT_Crack (13.760483264923096%)
# MT_Fray (18.309475481510162%)
# MT_Free (17.75362193584442%)
# MT_Uneven (18.10620427131653%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBLW004.jpg]:
# Top-1 (confidence)
# MT_Free (19.03138756752014%)
#
# With Transfer Learning [MTBLW004.jpg]:
# Top-1 (confidence)
# MT_Free (19.03138756752014%)
#
# Class (confidence)
# MT_Blowhole (16.909338533878326%)
# MT_Break (15.124183893203735%)
# MT_Crack (13.488912582397461%)
# MT_Fray (18.021264672279358%)
# MT_Free (19.03138756752014%)
# MT_Uneven (17.42490828037262%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTUNEVEN011.jpg]:
# Top-1 (confidence)
# MT_Free (19.200587272644043%)
#
# With Transfer Learning [MTUNEVEN011.jpg]:
# Top-1 (confidence)
# MT_Free (19.200587272644043%)
#
# Class (confidence)
# MT_Blowhole (16.545529663562775%)
# MT_Break (14.848119020462036%)
# MT_Crack (13.387779891490936%)
# MT_Fray (18.176595866680145%)
# MT_Free (19.200587272644043%)
# MT_Uneven (17.841391265392303%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBRK008.jpg]:
# Top-1 (confidence)
# MT_Free (18.830981850624084%)
#
# With Transfer Learning [MTBRK008.jpg]:
# Top-1 (confidence)
# MT_Free (18.830981850624084%)
#
# Class (confidence)
# MT_Blowhole (16.51007831096649%)
# MT_Break (14.138445258140564%)
# MT_Crack (13.166356086730957%)
# MT_Fray (18.72275322675705%)
# MT_Free (18.830981850624084%)
# MT_Uneven (18.631382286548615%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTCRK004.jpg]:
# Top-1 (confidence)
# MT_Free (19.105827808380127%)
#
# With Transfer Learning [MTCRK004.jpg]:
# Top-1 (confidence)
# MT_Free (19.105827808380127%)
#
# Class (confidence)
# MT_Blowhole (16.31733775138855%)
# MT_Break (14.530918002128601%)
# MT_Crack (13.355004787445068%)
# MT_Fray (17.76442676782608%)
# MT_Free (19.105827808380127%)
# MT_Uneven (18.926484882831573%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTUNEVEN013.jpg]:
# Top-1 (confidence)
# MT_Free (19.356198608875275%)
#
# With Transfer Learning [MTUNEVEN013.jpg]:
# Top-1 (confidence)
# MT_Free (19.356198608875275%)
#
# Class (confidence)
# MT_Blowhole (16.34979546070099%)
# MT_Break (14.564228057861328%)
# MT_Crack (13.332328200340271%)
# MT_Fray (18.47645491361618%)
# MT_Free (19.356198608875275%)
# MT_Uneven (17.921000719070435%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTUNEVEN019.jpg]:
# Top-1 (confidence)
# MT_Uneven (18.750597536563873%)
#
# With Transfer Learning [MTUNEVEN019.jpg]:
# Top-1 (confidence)
# MT_Uneven (18.750597536563873%)
#
# Class (confidence)
# MT_Blowhole (16.706499457359314%)
# MT_Break (13.953256607055664%)
# MT_Crack (14.199551939964294%)
# MT_Fray (17.721591889858246%)
# MT_Free (18.66850256919861%)
# MT_Uneven (18.750597536563873%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTCRK015.jpg]:
# Top-1 (confidence)
# MT_Free (18.476469814777374%)
#
# With Transfer Learning [MTCRK015.jpg]:
# Top-1 (confidence)
# MT_Free (18.476469814777374%)
#
# Class (confidence)
# MT_Blowhole (17.294399440288544%)
# MT_Break (15.00546783208847%)
# MT_Crack (12.952841818332672%)
# MT_Fray (18.43525320291519%)
# MT_Free (18.476469814777374%)
# MT_Uneven (17.835569381713867%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTCRK006.jpg]:
# Top-1 (confidence)
# MT_Free (18.485532701015472%)
#
# With Transfer Learning [MTCRK006.jpg]:
# Top-1 (confidence)
# MT_Free (18.485532701015472%)
#
# Class (confidence)
# MT_Blowhole (16.61343276500702%)
# MT_Break (14.431765675544739%)
# MT_Crack (14.4020214676857%)
# MT_Fray (18.173949420452118%)
# MT_Free (18.485532701015472%)
# MT_Uneven (17.893299460411072%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFREE024.jpg]:
# Top-1 (confidence)
# MT_Free (18.965770304203033%)
#
# With Transfer Learning [MTFREE024.jpg]:
# Top-1 (confidence)
# MT_Free (18.965770304203033%)
#
# Class (confidence)
# MT_Blowhole (16.646891832351685%)
# MT_Break (14.671085774898529%)
# MT_Crack (13.323372602462769%)
# MT_Fray (17.698663473129272%)
# MT_Free (18.965770304203033%)
# MT_Uneven (18.69421899318695%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTUNEVEN004.jpg]:
# Top-1 (confidence)
# MT_Fray (18.419399857521057%)
#
# With Transfer Learning [MTUNEVEN004.jpg]:
# Top-1 (confidence)
# MT_Fray (18.419399857521057%)
#
# Class (confidence)
# MT_Blowhole (16.449475288391113%)
# MT_Break (14.846454560756683%)
# MT_Crack (14.363063871860504%)
# MT_Fray (18.419399857521057%)
# MT_Free (18.04782897233963%)
# MT_Uneven (17.873775959014893%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTUNEVEN009.jpg]:
# Top-1 (confidence)
# MT_Free (19.294731318950653%)
#
# With Transfer Learning [MTUNEVEN009.jpg]:
# Top-1 (confidence)
# MT_Free (19.294731318950653%)
#
# Class (confidence)
# MT_Blowhole (16.168062388896942%)
# MT_Break (14.472661912441254%)
# MT_Crack (13.676071166992188%)
# MT_Fray (18.380853533744812%)
# MT_Free (19.294731318950653%)
# MT_Uneven (18.00762116909027%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTUNEVEN005.jpg]:
# Top-1 (confidence)
# MT_Free (19.01502013206482%)
#
# With Transfer Learning [MTUNEVEN005.jpg]:
# Top-1 (confidence)
# MT_Free (19.01502013206482%)
#
# Class (confidence)
# MT_Blowhole (16.973796486854553%)
# MT_Break (14.096076786518097%)
# MT_Crack (14.13528174161911%)
# MT_Fray (18.647107481956482%)
# MT_Free (19.01502013206482%)
# MT_Uneven (17.13271588087082%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFREE027.jpg]:
# Top-1 (confidence)
# MT_Free (19.546104967594147%)
#
# With Transfer Learning [MTFREE027.jpg]:
# Top-1 (confidence)
# MT_Free (19.546104967594147%)
#
# Class (confidence)
# MT_Blowhole (16.19332730770111%)
# MT_Break (14.56952691078186%)
# MT_Crack (13.398946821689606%)
# MT_Fray (17.62850731611252%)
# MT_Free (19.546104967594147%)
# MT_Uneven (18.663594126701355%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTCRK018.jpg]:
# Top-1 (confidence)
# MT_Fray (18.877094984054565%)
#
# With Transfer Learning [MTCRK018.jpg]:
# Top-1 (confidence)
# MT_Fray (18.877094984054565%)
#
# Class (confidence)
# MT_Blowhole (16.999785602092743%)
# MT_Break (14.929406344890594%)
# MT_Crack (13.530690968036652%)
# MT_Fray (18.877094984054565%)
# MT_Free (18.474705517292023%)
# MT_Uneven (17.188316583633423%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTBLW008.jpg]:
# Top-1 (confidence)
# MT_Free (19.963763654232025%)
#
# With Transfer Learning [MTBLW008.jpg]:
# Top-1 (confidence)
# MT_Free (19.963763654232025%)
#
# Class (confidence)
# MT_Blowhole (15.972934663295746%)
# MT_Break (14.81136828660965%)
# MT_Crack (13.854008913040161%)
# MT_Fray (18.872226774692535%)
# MT_Free (19.963763654232025%)
# MT_Uneven (16.525696218013763%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFREE011.jpg]:
# Top-1 (confidence)
# MT_Uneven (18.82559061050415%)
#
# With Transfer Learning [MTFREE011.jpg]:
# Top-1 (confidence)
# MT_Uneven (18.82559061050415%)
#
# Class (confidence)
# MT_Blowhole (16.542552411556244%)
# MT_Break (14.316684007644653%)
# MT_Crack (14.076285064220428%)
# MT_Fray (18.546169996261597%)
# MT_Free (17.692722380161285%)
# MT_Uneven (18.82559061050415%)
#
# ============================
#
# Without Transfer Learning Top-2 [MTFREE018.jpg]:
# Top-1 (confidence)
# MT_Free (18.72396618127823%)
#
# With Transfer Learning [MTFREE018.jpg]:
# Top-1 (confidence)
# MT_Free (18.72396618127823%)
#
# Class (confidence)
# MT_Blowhole (16.818858683109283%)
# MT_Break (14.570662379264832%)
# MT_Crack (13.596038520336151%)
# MT_Fray (18.097414076328278%)
# MT_Free (18.72396618127823%)
# MT_Uneven (18.193063139915466%)
#
# ============================

# %% [markdown]
# Catatan: Hasil yang lebih dulu di*print* adalah yang lebih dulu terbaca oleh ```os.listdir()```.

# %%
for directory in os.listdir(test_path):
    print(directory, end=' ')
# Out:
# MTFRY002.jpg MTUNEVEN002.jpg MTBLW007.jpg MTUNEVEN001.jpg MTUNEVEN016.jpg MTUNEVEN022.jpg MTBRK013.jpg MTFREE019.jpg MTCRK001.jpg MTBLW001.jpg MTBRK010.jpg MTFREE028.jpg MTCRK011.jpg MTFREE004.jpg MTBRK018.jpg MTFREE013.jpg MTBRK009.jpg MTFRY001.jpg MTBRK007.jpg MTUNEVEN021.jpg MTBLW003.jpg MTFREE017.jpg MTFREE021.jpg MTBLW005.jpg MTBRK005.jpg MTUNEVEN006.jpg MTBLW012.jpg MTFREE022.jpg MTFRY009.jpg MTBRK017.jpg MTUNEVEN007.jpg MTUNEVEN010.jpg MTFRY004.jpg MTFREE008.jpg MTFREE020.jpg MTBRK004.jpg MTCRK008.jpg MTBLW006.jpg MTFREE005.jpg MTFREE026.jpg MTBRK016.jpg MTBRK011.jpg MTUNEVEN008.jpg MTCRK016.jpg MTCRK010.jpg MTFREE025.jpg MTFREE010.jpg MTCRK017.jpg MTBRK012.jpg MTUNEVEN003.jpg MTUNEVEN012.jpg MTFREE003.jpg MTCRK005.jpg MTBLW010.jpg MTBLW016.jpg MTCRK014.jpg MTBLW015.jpg MTFREE023.jpg MTBRK014.jpg MTUNEVEN017.jpg MTFRY008.jpg MTCRK009.jpg MTBLW014.jpg MTUNEVEN020.jpg MTFRY003.jpg MTFRY006.jpg MTFREE006.jpg MTBLW009.jpg MTCRK013.jpg MTCRK003.jpg MTBRK019.jpg MTUNEVEN015.jpg MTBRK003.jpg MTFREE001.jpg MTUNEVEN014.jpg MTBRK015.jpg MTFRY005.jpg MTBRK006.jpg MTBRK002.jpg MTFREE009.jpg MTFREE016.jpg MTFREE012.jpg MTCRK002.jpg MTBLW002.jpg MTFREE002.jpg MTBLW013.jpg MTUNEVEN018.jpg MTFRY010.jpg MTFREE014.jpg MTCRK012.jpg MTFRY007.jpg MTFREE015.jpg MTBLW011.jpg MTCRK007.jpg MTBRK001.jpg MTFREE007.jpg MTBLW004.jpg MTUNEVEN011.jpg MTBRK008.jpg MTCRK004.jpg MTUNEVEN013.jpg MTUNEVEN019.jpg MTCRK015.jpg MTCRK006.jpg MTFREE024.jpg MTUNEVEN004.jpg MTUNEVEN009.jpg MTUNEVEN005.jpg MTFREE027.jpg MTCRK018.jpg MTBLW008.jpg MTFREE011.jpg MTFREE018.jpg

# %% [markdown]
# ### Selesai!
#
# Sesuai motivasi dibuatnya Keras sendiri "*easy and fast prototyping*", notebook ini dibuat generik.
#
# Sumber : https://github.com/tbmreza/comvis-notes/blob/master/transfer-learning.ipynb
#
# dengan beberapa penyesuaian
